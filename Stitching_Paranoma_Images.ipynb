# %%
import cv2
import matplotlib.pyplot as plt

# %%
img1=cv2.imread("boat/boat1.jpg")
img2=cv2.imread("boat/boat2.jpg")
img3=cv2.imread("boat/boat3.jpg")
img4=cv2.imread("boat/boat4.jpg")
img5=cv2.imread("boat/boat5.jpg")
img6=cv2.imread("boat/boat6.jpg")

img_list=[img1,img2,img3,img4,img5,img6]

# %%
stich=cv2.Stitcher_create()
s,result=stich.stitch(img_list)

# %%
print(s)
# Out:
# 0

# %%
plt.imshow(result)
